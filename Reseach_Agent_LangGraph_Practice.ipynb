# %% [markdown]
# <a href="https://colab.research.google.com/github/nawab-noddy/AI-ML-Proejcts/blob/main/Reseach_Agent_LangGraph_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from langchain.tools import tool

# %%
pip install langchain_groq

# %%
from langchain_groq import ChatGroq

# %%
from google.colab import userdata
userdata.get('GROQ_API_KEY')

# %%
llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0,
    max_tokens=1024,
    api_key=GROQ_API_KEY
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# J'aime la programmation.

# %%
pip install tavily

# %%
from tavily import TavilyClient

# %%
from google.colab import userdata
userdata.get('tavily_client')

# %%
tavily_client = TavilyClient(api_key='tavily_client')

# %%
from langchain.tools import tool

# %%
@tool
def internet_search(query: str,max_results: int = 5) ->dict:
    """Search the internet for relevant sources."""
    return tavily_client.search(
        query,
        max_results=max_results
    )

# %% [markdown]
# Will Do many thngs Tomorrow

# %%
print("Hello World")
# Out:
# Hello World
